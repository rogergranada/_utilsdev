# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1, 100, 0.1)
y = np.random.choice(1000000, x.shape)

#plt.plot()
print x.shape
print y.shape
# Out:
# (990,)
# (990,)

# %%
plt.plot(x, y)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
#plt.show()
plt.savefig('img.png' )
