# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import cv2
# Out:
# /home/roger/.anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
img = cv2.imread("/home/roger/Desktop/colors.jpg")

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
plt.imshow(hsv2)
print 'Shape: ', hsv.shape
# Out:
# Shape:  (480, 640, 3)

# %%
blue_min = np.array([160, 100, 100], dtype="uint8")
blue_max = np.array([179, 255, 255], dtype="uint8")


red_min = np.array([0, 100, 100], dtype = "uint8")
red_max = np.array([10, 255, 255], dtype = "uint8")
mask = cv2.inRange(hsv, blue_min, blue_max)
plt.imshow(mask, cmap='gray')

# %%
if(name=="blue"){

		//TODO: use "calibration mode" to find HSV min
		//and HSV max values

		setHSVmin(Scalar());
		setHSVmax(Scalar());

		//BGR value for Blue:
		setColor(Scalar(255,0,0));

	}
	if(name=="green"){

		//TODO: use "calibration mode" to find HSV min
		//and HSV max values

		setHSVmin(Scalar(34,50,50));
		setHSVmax(Scalar(80,220,200));

		//BGR value for Green:
		setColor(Scalar(0,255,0));

	}
	if(name=="yellow"){

		//TODO: use "calibration mode" to find HSV min
		//and HSV max values

		setHSVmin(Scalar(20,124,123));
		setHSVmax(Scalar(30,256,256));

		//BGR value for Yellow:
		setColor(Scalar(0,255,255));

	}
	if(name=="red"){

		//TODO: use "calibration mode" to find HSV min
		//and HSV max values

		setHSVmin(Scalar(0,200,0));
		setHSVmax(Scalar(19,255,255));

		//BGR value for Red:
		setColor(Scalar(0,0,255));

	}
